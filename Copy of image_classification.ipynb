# %%
import os

# %%
os.getcwd()
# Out:
# '/content'

# %% [markdown]
# **importing the keras libraries**

# %%
from keras.models import Sequential
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense

# %% [markdown]
# **Initialize the concolution neural network**

# %%
classifier = Sequential()

# %% [markdown]
# **Part - 1**

# %% [markdown]
# step 1 - convolution

# %%
classifier.add(Convolution2D(32, 3, 3, border_mode='same', input_shape=(64,64, 3), activation='relu' ))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), input_shape=(64, 64, 3..., activation="relu", padding="same")`
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# step 2 - Pooling

# %%
classifier.add(MaxPooling2D(pool_size = (2,2)))

# %% [markdown]
# **step 3 - Flattening**

# %%
classifier.add(Flatten())

# %% [markdown]
# **Step 4 - Full Connection**

# %%
classifier.add(Dense(output_dim =128 , activation='relu'))
classifier.add(Dense(output_dim = 1  , activation='sigmoid'))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=128)`
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="sigmoid", units=1)`

# %%
classifier.compile(optimizer='adam', loss = 'binary_crossentropy' , metrics=['accuracy'])

# %% [markdown]
# **part - 2** fitting the CNN to image

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

# %%
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
training_set = train_datagen.flow_from_directory(
        '/content/drive/My Drive/Colab Notebooks/P16-Convolutional-Neural-Networks.zip (Unzipped Files)/Part 2 - Convolutional Neural Networks/dataset/training_set',
        target_size=(64, 64),
        batch_size=32,
        class_mode='binary')
# Out:
# Found 8002 images belonging to 2 classes.

# %%
/content/sample_data

# %%
test_set = test_datagen.flow_from_directory(
        '/content/drive/My Drive/Colab Notebooks/P16-Convolutional-Neural-Networks.zip (Unzipped Files)/Part 2 - Convolutional Neural Networks/dataset/test_set',
        target_size=(64, 64),
        batch_size=32,
        class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %%
classifier.fit(
        training_set,
        steps_per_epoch=8002,
        epochs=25,
        validation_data=test_set,
        validation_steps=2000)
# Out:
# Epoch 1/25
#    8/8002 [..............................] - ETA: 22:25:43 - loss: 1.7035 - accuracy: 0.5547
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-e98e80fe231b> in <module>()
#       5         epochs=25,
#       6         validation_data=test_set,
# ----> 7         validation_steps=2000)
#       8
#       9
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1145                 use_multiprocessing=use_multiprocessing,
#    1146                 shuffle=shuffle,
# -> 1147                 initial_epoch=initial_epoch)
#    1148
# ...
